# %%
import pandas as pd
from pandas import DataFrame
import csv
import numpy as np

import datetime
import pytz

# %%
# if you want to mount google drive to pull files and write files in your cloud storage
# from google.colab import drive

# %%
# if you want to mount google drive to pull files and write files in your cloud storage
# drive.mount('/content/gdrive')

# %%
# if you want to mount google drive to pull files and write files in your cloud storage
path_to_this_dir = "/content/gdrive/MyDrive/Colab Notebooks/my_projects/big_papa_as400_to_website_comparison/"

# %%
# df_papa_as_400 = pd.read_csv(path_to_this_dir + "as_400.csv") # if you want to mount google drive to pull files and write files in your cloud storage 
df_papa_as_400 = pd.read_csv("as_400.csv")

# %%
print(df_papa_as_400.shape)
df_papa_as_400.info()
# Out:
# (962, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ORDER                           962 non-null    object
#  1   SOLD TO                         962 non-null    object
#  2   ST                              962 non-null    object
#  3   RM                              962 non-null    int64
#  4   RD                              962 non-null    int64
#  5   RY                              962 non-null    int64
#  6   PO#                             962 non-null    object
#  7   ASN                             962 non-null    object
#  8   LOC                             962 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 67.8+ KB

# %%
df_papa_as_400.head()
# Out:
#    ORDER   SOLD TO                         ST  RM  RD  RY  \
# 0  EL1469  Ventura Unified Warehouse       SH   5   8  23
# 1  EL2148  Boundless Communication Soluti  OB   5   8  23
# 2  EL2490  Gunmook O                       OB   5   5  23
# 3  EL2568  Binghamton University Decker S  OB   5  19  23
# 4  EL2106  Rebecca Maxey                   OB   5   9  23
#
#    PO#                  ASN  LOC
# 0  Gv7Vv0Xkc              C   75
# 1  GW75PXKKc              C   69
# 2  G7Rt4bq7Q                   1
# 3  GfwyM3nBQ                  69
# 4  GhwctjKKc              P   60

# %%
# df_papa_website = pd.read_csv(path_to_this_dir + "website.csv") # if you want to mount google drive to pull files and write files in your cloud storage
df_papa_website = pd.read_csv("website.csv")

# %%
df_papa_website.head()
# Out:
#     Order ID Order Status Warehouse Code             Order Place Date  \
# 0  Ghmq41xNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 1  GBmV4jxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 2  Gqm34kxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 3  G7mp47xNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 4  GtmK4mxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
#
#            Required Ship Date Ship Method Ship Method Code   Ship To Name  \
# 0  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 1  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 2  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 3  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 4  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
#
#   Ship To Address Line 1 Ship To Address Line 2  ...  Phone Number  \
# 0      4949 W BETHANY RD                    NaN  ...    5013740812
# 1      4949 W BETHANY RD                    NaN  ...    5013740812
# 2      4949 W BETHANY RD                    NaN  ...    5013740812
# 3      4949 W BETHANY RD                    NaN  ...    5013740812
# 4      4949 W BETHANY RD                    NaN  ...    5013740812
#
#   Is it Gift?  Item Cost      SKU        ASIN  \
# 0          No  $2,240.95  112000P  B01GS68CB8
# 1          No  $2,240.95  112000P  B01GS68CB8
# 2          No  $2,240.95  112000P  B01GS68CB8
# 3          No  $2,240.95  112000P  B01GS68CB8
# 4          No  $2,240.95  112000P  B01GS68CB8
#
#                                           Item Title Item Quantity  \
# 0  HP Papers Printer Paper, 8.5 x 11 paper, Multi...             2
# 1  HP Papers Printer Paper, 8.5 x 11 paper, Multi...             2
# 2  HP Papers Printer Paper, 8.5 x 11 paper, Multi...             2
# 3  HP Papers Printer Paper, 8.5 x 11 paper, Multi...             2
# 4  HP Papers Printer Paper, 8.5 x 11 paper, Multi...             2
#
#   Gift Message Tracking ID Shipped Date
# 0          NaN         NaN          NaN
# 1          NaN         NaN          NaN
# 2          NaN         NaN          NaN
# 3          NaN         NaN          NaN
# 4          NaN         NaN          NaN
#
# [5 rows x 25 columns]

# %%
print(df_papa_website.shape)
df_papa_website.info()
# Out:
# (735, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735 entries, 0 to 734
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order ID                735 non-null    object
#  1   Order Status            735 non-null    object
#  2   Warehouse Code          735 non-null    object
#  3   Order Place Date        735 non-null    object
#  4   Required Ship Date      735 non-null    object
#  5   Ship Method             735 non-null    object
#  6   Ship Method Code        735 non-null    object
#  7   Ship To Name            735 non-null    object
#  8   Ship To Address Line 1  735 non-null    object
#  9   Ship To Address Line 2  83 non-null     object
#  10  Ship To Address Line 3  0 non-null      float64
#  11  Ship To City            735 non-null    object
#  12  Ship To State           735 non-null    object
#  13  Ship To ZIP Code        735 non-null    object
#  14  Ship To Country         735 non-null    object
#  15  Phone Number            711 non-null    object
#  16  Is it Gift?             735 non-null    object
#  17  Item Cost               735 non-null    object
#  18  SKU                     735 non-null    object
#  19  ASIN                    735 non-null    object
#  20  Item Title              735 non-null    object
#  21  Item Quantity           735 non-null    int64
#  22  Gift Message            9 non-null      object
#  23  Tracking ID             649 non-null    object
#  24  Shipped Date            0 non-null      float64
# dtypes: float64(2), int64(1), object(22)
# memory usage: 143.7+ KB

# %%
# renaming columns
df_papa_website = df_papa_website.rename(columns={'Order ID': 'amz_order_num',
                                                  'Order Place Date': 'order_place_date',
                                                  'Required Ship Date': 'req_ship_date',
                                                  'Ship Method': 'ship_method',
                                                  'Tracking ID': 'tracking_id'})

# %%
# renaming columns
df_papa_as_400 = df_papa_as_400.rename(columns={df_papa_as_400.columns[0]: 'tst_order_num', 
                                                df_papa_as_400.columns[1]: 'SOLD_TO',
                                                df_papa_as_400.columns[2]: 'STATUS',
                                                df_papa_as_400.columns[3]: 'RM',
                                                df_papa_as_400.columns[4]: 'RD',
                                                df_papa_as_400.columns[5]: 'RY', 
                                                df_papa_as_400.columns[6]: 'amz_order_num',
                                                df_papa_as_400.columns[7]: 'ASN',
                                                df_papa_as_400.columns[8]: 'location'})

# %%
as_400_amz_order_arr = df_papa_as_400['amz_order_num'].to_numpy()
# there was 11 characters of whitespace in the as400 amazon order #s that needed to ditch
for index, order_num in enumerate(as_400_amz_order_arr):
  as_400_amz_order_arr[index] = order_num.strip()
print(as_400_amz_order_arr)
# Out:
# ['Gv7Vv0Xkc' 'GW75PXKKc' 'G7Rt4bq7Q' 'GfwyM3nBQ' 'GhwctjKKc' 'GWJZ5k4Vc'
#  'GxmJ5G5Sc' 'GvFRJdsRc' 'GtctHsvkc' 'GvYR5zKPc' 'G47X99PBQ' 'Gxsy9Bp1Q'
#  'GxmjLnntQ' 'GsZG5wKRc' 'Gs6WNfPMQ' 'GHPZt143c' 'Gv2WqtnQQ' 'GqcYH7KFc'
#  'Gq4v1DjQv' 'GsBnJCKTc' 'GvNFnXn1Q' 'G72x4wKYc' 'GsT6tkn8Q' 'Gk68r2K6c'
#  'GfcxrtKGc' 'GhVx6bPKQ' 'GWqH7DPsQ' 'G41sDmXjc' 'GW2LntKNc' 'GBHC5yKQc'
#  'Gqhf78pqQ' 'GhNtLlmVc' 'GHlYf3pwQ' 'GfMxDxNfc' 'GfqdWSn6Q' 'Gt44PJK0c'
#  'Gx2lc6Knc' 'GsnL1sKvc' 'GvHQy4pRQ' 'Gs0YHYP3Q' 'Gtzl7JpBQ' 'GqJQfFv2c'
#  'GWlC0jnxQ' 'GtDbJ8KSc' 'Gfj4gJ4mc' 'GtRz1GprQ' 'GhBzsKXmc' 'Gfp2WJK4c'
#  'GqgMyyp5Q' 'GvJFPqXKc' 'G7FlJ3Xpc' 'Gsqk1FXhc' 'G7q2RvKBc' 'Gxhp00nxQ'
#  'GsL5X0KYc' 'GWlrTcXzc' 'G43x8JpyQ' 'G7VllMXMc' 'Ghxc0zKwc' 'GsxRlLKdc'
#  'Gqt9S8KXc' 'GHKY3pKZc' 'GfjSX4vlc' 'GtwhXbKFc' 'GHsW9wKQc' 'GWwYCTn3Q'
#  'GvJYR8PVQ' 'Gx2pZHXhc' 'Gh2dGlPFQ' 'GhwbDNplQ' 'Ghny3mnrQ' 'GqYZkcPQQ'
#  'G7Hj3WXBc' 'Gvz6knKyc' 'G4QD75KCc' 'GWVLtcpkQ' 'Gqr3yL0Sc' 'Gq4HyRXKc'
#  'GvYPWQpmQ' 'Gv4Q0ynBQ' 'GtTB7RKlc' 'GBNFmzXGc' 'GHGvmJXFc' 'GHmwzqPLQ'
#  'GtTBh0K2c' 'GfSsxWXKc' 'GvsZktKVc' 'Gqc0f54Qv' 'GkSPdRK4c' 'GvTVtkn8Q'
#  'G7y4yspfQ' 'GxwThxXdc' 'Gql0DFKvc' 'Gt3g3SKkc' 'GvC56MXdc' 'G7M7d2Xnc'
#  'GtqXjwncQ' 'Ghj4kmXkc' 'GhTxmfqBQ' 'GB2ftrKHc' 'GsKQ3qKZc' 'GWSrCRvVc'
#  'GBNYVyPmQ' 'GfLD4wKBc' 'G7jXgJ4mc' 'G4Y1WhKCc' 'GB9vm8Kqc' 'GvNPMynfQ'
#  'GqTC8TnxQ' 'Gqr61QMDc' 'GqJM7gnCQ' 'G4PgJ7Ktc' 'Gv89kfPSQ' 'GtfNdpKbc'
#  'GW25fxnGQ' 'GWt6FTPRQ' 'GBLFFTXsc' 'GBk3sCpWQ' 'GqxQRdKHc' 'GvMWd2Xnc'
#  'GtqDjGKBc' 'GB3k6TNGv' 'GkhGKlXMc' 'Gf6XRQpHQ' 'GWXPfyKzc' 'Gx34cpRlc'
#  'GslPxypLQ' 'G7S4BynnQ' 'GtshjZXQc' 'GkRQsJXyc' 'GfNsK5nxQ' 'GxW4yQpSQ'
#  'GfsxkQPJQ' 'GB2MfXK2c' 'GkFQdvXvc' 'GfcTH7KFc' 'GvjHQRnxQ' 'GxHtK8Kmc'
#  'GqX5PgpcQ' 'GH4mPxK0c' 'Gvn8cBpYQ' 'GWkrwTKnc' 'GHyZP4Kbc' 'GhK701N5c'
#  'GHXV8QqNQ' 'G4pdjln9Q' 'Gh4pjbXMc' 'GqKMjvngQ' 'GHnmBzP0Q' 'GkWRyqK9c'
#  'G7TzrCKRc' 'GHxr30zXc' 'GqX8BFXLc' 'G4h4X7XYc' 'GfGxSmX0c' 'Gf0bWLKlc'
#  'GWFQTnKFc' 'GkF51WKbc' 'G7RD1YKKc' 'GtShPWnSQ' 'G4jtPg5Lc' 'Gq9f3Jp1Q'
#  'G4Wly6pSQ' 'GHB57kPXQ' 'G7d7zZXJc' 'GWS5bQK3c' 'GsNVrhpwQ' 'G4rbCCnrQ'
#  'G7gDWgnWQ' 'Gqm34kxNc' 'G4ZqQSKMc' 'Gx5gsS54c' 'Gt5K0fPmQ' 'GfSbjhnRQ'
#  'GvMP6cKRc' 'Gh7X06nfQ' 'GhsBHfpkQ' 'G4Sh4vPlQ' 'G7ttQrXvc' 'GW6GGvKWc'
#  'GqRCG3ntQ' 'GxcpQgpDQ' 'Gv9Z6Gp5Q' 'GWx6dJKpc' 'GqqwvKXFc' 'GhkBsCpWQ'
#  'G4nh0hPsQ' 'GH2Fmqp7Q' 'Gfwd1XKfc' 'G727qtnQQ' 'GHm39MPDQ' 'G4mjhMKDc'
#  'GH2Wvd5fc' 'GsMQLvnFQ' 'GksQjbXQc' 'Gk98Qtn1Q' 'GxLd9zP9Q' 'GHn63knrQ'
#  'GtG4N1PZQ' 'G7yl3hKfc' 'Gtj14LXMc' 'GsCRPcnbQ' 'GWmWDKKYc' 'GWGn0CKHc'
#  'GtNX7JppQ' 'GkjQgx4mc' 'Gs7M06nfQ' 'GB29mPp7Q' 'G4K13nKZc' 'G7Jz534Vc'
#  'GqR62Cxzc' 'GvgQFMPqQ' 'GvXr7tq6Q' 'Gqf38YK8c' 'GhKdKLnQQ' 'GsTQWWKsc'
#  'GBV9C0nyQ' 'G7Ngnvn1Q' 'G4tcmBntQ' 'GBKW9JPyQ' 'GsjPdjpWQ' 'GkqWWqKgc'
#  'GB53lgp5Q' 'Gt9zhNKyc' 'G7JKV8nPQ' 'GvnrBCKqc' 'Ghn4nmKVc' 'GBJ9HYqnQ'
#  'GBJ9G4XRc' 'Gx1BHKPNQ' 'GhSJ54PrQ' 'Gs4RkFpgQ' 'GHqMjwncQ' 'GvXYf8Kyc'
#  'Gh9hBWpXQ' 'Gv1wMdK3c']

# %%
# adding origin column since combining as400 orders and website orders to be able to distinguish where they came from
df_papa_as_400['origin'] = 'as400'
df_papa_as_400.head()
# Out:
#   tst_order_num                         SOLD_TO STATUS  RM  RD  RY  \
# 0        EL1469  Ventura Unified Warehouse          SH   5   8  23
# 1        EL2148  Boundless Communication Soluti     OB   5   8  23
# 2        EL2490  Gunmook O                          OB   5   5  23
# 3        EL2568  Binghamton University Decker S     OB   5  19  23
# 4        EL2106  Rebecca Maxey                      OB   5   9  23
#
#   amz_order_num ASN  location origin
# 0     Gv7Vv0Xkc   C        75  as400
# 1     GW75PXKKc   C        69  as400
# 2     G7Rt4bq7Q             1  as400
# 3     GfwyM3nBQ            69  as400
# 4     GhwctjKKc   P        60  as400

# %%
# adding origin column since combining as400 orders and website orders to be able to distinguish where they came from
df_papa_website['origin'] = 'website'
df_papa_website.head()
# Out:
#   amz_order_num Order Status Warehouse Code             order_place_date  \
# 0     Ghmq41xNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 1     GBmV4jxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 2     Gqm34kxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 3     G7mp47xNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
# 4     GtmK4mxNc          NEW           BHHV  Apr 24, 2023 4:47:00 PM GMT
#
#                 req_ship_date ship_method Ship Method Code   Ship To Name  \
# 0  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 1  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 2  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 3  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
# 4  May 1, 2023 8:00:00 PM GMT   VOC_IMSZY        VOC_IMSZY  RACHAEL POOLE
#
#   Ship To Address Line 1 Ship To Address Line 2  ...  Is it Gift?  Item Cost  \
# 0      4949 W BETHANY RD                    NaN  ...           No  $2,240.95
# 1      4949 W BETHANY RD                    NaN  ...           No  $2,240.95
# 2      4949 W BETHANY RD                    NaN  ...           No  $2,240.95
# 3      4949 W BETHANY RD                    NaN  ...           No  $2,240.95
# 4      4949 W BETHANY RD                    NaN  ...           No  $2,240.95
#
#        SKU        ASIN                                         Item Title  \
# 0  112000P  B01GS68CB8  HP Papers Printer Paper, 8.5 x 11 paper, Multi...
# 1  112000P  B01GS68CB8  HP Papers Printer Paper, 8.5 x 11 paper, Multi...
# 2  112000P  B01GS68CB8  HP Papers Printer Paper, 8.5 x 11 paper, Multi...
# 3  112000P  B01GS68CB8  HP Papers Printer Paper, 8.5 x 11 paper, Multi...
# 4  112000P  B01GS68CB8  HP Papers Printer Paper, 8.5 x 11 paper, Multi...
#
#   Item Quantity Gift Message tracking_id Shipped Date   origin
# 0             2          NaN         NaN          NaN  website
# 1             2          NaN         NaN          NaN  website
# 2             2          NaN         NaN          NaN  website
# 3             2          NaN         NaN          NaN  website
# 4             2          NaN         NaN          NaN  website
#
# [5 rows x 26 columns]

# %%
# drop all of the columns that you don't care about 
df_papa_website.drop(columns=['Order Status',
                              'Warehouse Code',
                              'Ship Method Code',
                              'Ship To Name',
                              'Ship To Address Line 1',
                              'Ship To Address Line 2',
                              'Ship To Address Line 3',
                              'Ship To City',
                              'Ship To State',
                              'Ship To ZIP Code',
                              'Ship To Country',
                              'Phone Number',
                              'Is it Gift?',
                              'Item Cost',
                              'SKU',
                              'ASIN',
                              'Item Title',
                              'Item Quantity',
                              'Gift Message',
                              'Shipped Date'], axis=1, inplace=True)
df_papa_website.head()
# Out:
#   amz_order_num             order_place_date               req_ship_date  \
# 0     Ghmq41xNc  Apr 24, 2023 4:47:00 PM GMT  May 1, 2023 8:00:00 PM GMT
# 1     GBmV4jxNc  Apr 24, 2023 4:47:00 PM GMT  May 1, 2023 8:00:00 PM GMT
# 2     Gqm34kxNc  Apr 24, 2023 4:47:00 PM GMT  May 1, 2023 8:00:00 PM GMT
# 3     G7mp47xNc  Apr 24, 2023 4:47:00 PM GMT  May 1, 2023 8:00:00 PM GMT
# 4     GtmK4mxNc  Apr 24, 2023 4:47:00 PM GMT  May 1, 2023 8:00:00 PM GMT
#
#   ship_method tracking_id   origin
# 0   VOC_IMSZY         NaN  website
# 1   VOC_IMSZY         NaN  website
# 2   VOC_IMSZY         NaN  website
# 3   VOC_IMSZY         NaN  website
# 4   VOC_IMSZY         NaN  website

# %%
# drop the columns that you don't care about
df_papa_as_400.drop(columns=['SOLD_TO',
                             'RM',
                             'RD',
                             'RY'], axis=1, inplace=True)
df_papa_as_400.head()
# Out:
#   tst_order_num STATUS amz_order_num ASN  location origin
# 0        EL1469     SH     Gv7Vv0Xkc   C        75  as400
# 1        EL2148     OB     GW75PXKKc   C        69  as400
# 2        EL2490     OB     G7Rt4bq7Q             1  as400
# 3        EL2568     OB     GfwyM3nBQ            69  as400
# 4        EL2106     OB     GhwctjKKc   P        60  as400

# %%
# combining the as400 and website dataframes into one new dataframe
df_altogether = pd.concat([df_papa_as_400, df_papa_website], axis=0)
df_altogether.head()
# Out:
#   tst_order_num STATUS amz_order_num ASN  location origin order_place_date  \
# 0        EL1469     SH     Gv7Vv0Xkc   C      75.0  as400              NaN
# 1        EL2148     OB     GW75PXKKc   C      69.0  as400              NaN
# 2        EL2490     OB     G7Rt4bq7Q           1.0  as400              NaN
# 3        EL2568     OB     GfwyM3nBQ          69.0  as400              NaN
# 4        EL2106     OB     GhwctjKKc   P      60.0  as400              NaN
#
#   req_ship_date ship_method tracking_id
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN

# %%
df_altogether.head(-10)
# Out:
#     tst_order_num STATUS amz_order_num  ASN  location   origin  \
# 0          EL1469     SH     Gv7Vv0Xkc    C      75.0    as400
# 1          EL2148     OB     GW75PXKKc    C      69.0    as400
# 2          EL2490     OB     G7Rt4bq7Q            1.0    as400
# 3          EL2568     OB     GfwyM3nBQ           69.0    as400
# 4          EL2106     OB     GhwctjKKc    P      60.0    as400
# ..            ...    ...           ...  ...       ...      ...
# 720           NaN    NaN     GvN5rzpwQ  NaN       NaN  website
# 721           NaN    NaN     GhLB8rppQ  NaN       NaN  website
# 722           NaN    NaN     GBx6KGpBQ  NaN       NaN  website
# 723           NaN    NaN     G4276mpQQ  NaN       NaN  website
# 724           NaN    NaN     Ghw26NpPQ  NaN       NaN  website
#
#                order_place_date                req_ship_date  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 720  May 5, 2023 6:01:06 PM GMT   May 8, 2023 9:00:00 PM GMT
# 721  May 5, 2023 6:03:33 PM GMT   May 9, 2023 8:00:00 PM GMT
# 722  May 5, 2023 6:01:33 PM GMT   May 9, 2023 8:00:00 PM GMT
# 723  May 5, 2023 6:06:46 PM GMT  May 8, 2023 11:00:00 PM GMT
# 724  May 5, 2023 6:16:11 PM GMT   May 9, 2023 8:00:00 PM GMT
#
#                  ship_method                            tracking_id
# 0                        NaN                                    NaN
# 1                        NaN                                    NaN
# 2                        NaN                                    NaN
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
# ..                       ...                                    ...
# 720  UPS Surepost GRD Parcel  1ZB348D6YW05453343&1ZB348D6YW02147617
# 721    UPS Ground Commercial  1ZB348D60311345152&1ZB348D60311736560
# 722    UPS Ground Commercial                     1ZB348D60339372473
# 723  UPS Surepost GRD Parcel                     1ZB348D6YW01782352
# 724   UPS Ground Residential                                    NaN
#
# [1687 rows x 10 columns]

# %%
# counting # of occurences of the amazon order # 
# since both as400 and website are together now, there should be 2 occurrences of each order # if an order is found on both sides
order_counts = df_altogether['amz_order_num'].value_counts()
order_counts_dict = order_counts.to_dict()
# adding the # of times that you find the amazon order # as a column for each order
df_altogether['num_occurences'] = df_altogether['amz_order_num'].map(order_counts_dict)

# %%
df_altogether.head(500)
# Out:
#     tst_order_num STATUS amz_order_num ASN  location origin order_place_date  \
# 0          EL1469     SH     Gv7Vv0Xkc   C      75.0  as400              NaN
# 1          EL2148     OB     GW75PXKKc   C      69.0  as400              NaN
# 2          EL2490     OB     G7Rt4bq7Q           1.0  as400              NaN
# 3          EL2568     OB     GfwyM3nBQ          69.0  as400              NaN
# 4          EL2106     OB     GhwctjKKc   P      60.0  as400              NaN
# ..            ...    ...           ...  ..       ...    ...              ...
# 495        EL2981     OB     GxQz3lprQ          69.0  as400              NaN
# 496        EL1838     OB     GtgdmyXwc   C      69.0  as400              NaN
# 497        EL2099     OB     GkQ6t1Kgc   P      60.0  as400              NaN
# 498        EL2895     OB     GBmCbPpyQ          69.0  as400              NaN
# 499        EL2335     SH     GvrP91PsQ   C      75.0  as400              NaN
#
#     req_ship_date ship_method tracking_id  num_occurences
# 0             NaN         NaN         NaN               1
# 1             NaN         NaN         NaN               1
# 2             NaN         NaN         NaN               2
# 3             NaN         NaN         NaN               2
# 4             NaN         NaN         NaN               2
# ..            ...         ...         ...             ...
# 495           NaN         NaN         NaN               2
# 496           NaN         NaN         NaN               1
# 497           NaN         NaN         NaN               2
# 498           NaN         NaN         NaN               2
# 499           NaN         NaN         NaN               1
#
# [500 rows x 11 columns]

# %%
# find all of the unmatched orders and save in as400 not on website and website not in as400 lists
orders_in_as400_not_on_website = []
orders_on_website_not_in_as400 = []
for i in range(len(df_altogether)):
  if df_altogether.iloc[i].loc['num_occurences'] == 1:
    if pd.isna(df_altogether.iloc[i].loc['tst_order_num']): # website orders that are unmatched will have nan for tst_order_num
      orders_on_website_not_in_as400.append(df_altogether.iloc[i].loc['amz_order_num'])
    else: # if there is a tst_order_num and num_occurences is 1, then the order is found in as400 but not on website
      # saving info that you care about: tst_order_num, amz_order_num, STATUS, location
      orders_in_as400_not_on_website.append([df_altogether.iloc[i].loc['tst_order_num'], df_altogether.iloc[i].loc['amz_order_num'], df_altogether.iloc[i].loc['STATUS'], df_altogether.iloc[i].loc['location']])
      
# sorting as400 orders by status to be able to see SH, CN etc altogether
# because SH pretty much implies that's why the order is in as400 but not on website because ASN was already sent, but order still in open orders in as400
sorted_as_400_list_by_status = sorted(orders_in_as400_not_on_website, key=lambda x: x[2]) # x[2] is the STATUS column
print('orders_in_as400_not_on_website')
for i in range(len(sorted_as_400_list_by_status)):
  print(sorted_as_400_list_by_status)
  print(f"{sorted_as_400_list_by_status[i][0]} {sorted_as_400_list_by_status[i][1]} {sorted_as_400_list_by_status[i][2]} {sorted_as_400_list_by_status[i][3]}")
  
print('\n')
print('orders_on_website_not_in_as400')
for i in range(len(orders_on_website_not_in_as400)):
.0], ['EK6123', 'Gx725q6Dc', 'SH', 1.0], ['EL2354', 'GBKrHmPCQ', 'SH', 75.0], ['EL2032', 'GHTW7pKlc', 'SH', 75.0], ['EL2478', 'GvxZXPPxQ', 'SH', 60.0], ['EL2479', 'GhTjCgPwQ', 'SH', 75.0], ['EL2006', 'GWsHLDKWc', 'SH', 75.0], ['EL1715', 'Gffs87XSc', 'SH', 60.0], ['EL1849', 'GkFmRtKLc', 'SH', 60.0], ['EL1773', 'GtKckpKqc', 'SH', 60.0], ['EL1916', 'Ghspwl ...
# EL2486 GBJ9HYqnQ SH 75.0
#
#
# orders_on_website_not_in_as400
# GvQfswsPc
# GhlzMwsPc
# GW3Hsfsmc
# GqHMsjsZc
# GxJXLFszc
# Gqvfccs5c
# GBpPM8szc
# GvKYh5fNc

# %%
# write unmatched orders to csv file
filename = 'unmatched_orders.csv'
with open(filename, 'w') as csvfile:
  csvwriter = csv.writer(csvfile)

  csvwriter.writerow(['ORDERS FOUND IN AS400 BUT NOT FOUND ON WEBSITE:'])
  for order in sorted_as_400_list_by_status:
    one_line = []
    one_line.append(order[0])
    one_line.append(order[1])
    one_line.append(order[2])
    one_line.append(order[3])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['ORDERS FOUND ON WEBSITE BUT NOT FOUND IN AS400:'])
  for order in orders_on_website_not_in_as400:
    csvwriter.writerow([order])

# %% [markdown]
# ok found all of the unmatched orders website and as400<br>
# now find all of the orders that are late on the website and group by plant

# %%
# need to continue to check that this is the way Amazon abbreviates months as time proceeds...
month_abbreviations_to_digits = {
    "Jan": "01",
    "Feb": "02",
    "Mar": "03",
    "Apr": "04",
    "May": "05",
    "June": "06",
    "July": "07",
    "Aug": "08",
    "Sept": "09",
    "Oct": "10",
    "Nov": "11",
    "Dec": "12"
}

# %%
# add the order required ship by dates that you will build to the dataframe
req_ship_date_diff_format = []
for i in range(len(df_altogether)):
  if df_altogether.iloc[i].loc['origin'] == 'website':
    split_up_one_date = df_altogether.iloc[i].loc['req_ship_date'].split()
    split_up_one_date[1] = split_up_one_date[1].replace(',', '') # remove comma after day # 
    # add leading 0 to day if 1 digit to begin with
    if len(split_up_one_date[1]) == 1:
      split_up_one_date[1] = "0" + split_up_one_date[1]

    # build formatted date string convert month abbreviation to 2 digit month
    date_to_build = split_up_one_date[2] + "-" + month_abbreviations_to_digits[split_up_one_date[0]] + "-" + split_up_one_date[1]
    req_ship_date_diff_format.append(date_to_build)
  else:
    req_ship_date_diff_format.append(np.nan)

# add formatted dates as new column in dataframe
df_altogether['req_ship_date_diff_format'] = req_ship_date_diff_format
df_altogether.head(-10)
# Out:
#     tst_order_num STATUS amz_order_num  ASN  location   origin  \
# 0          EL1469     SH     Gv7Vv0Xkc    C      75.0    as400
# 1          EL2148     OB     GW75PXKKc    C      69.0    as400
# 2          EL2490     OB     G7Rt4bq7Q            1.0    as400
# 3          EL2568     OB     GfwyM3nBQ           69.0    as400
# 4          EL2106     OB     GhwctjKKc    P      60.0    as400
# ..            ...    ...           ...  ...       ...      ...
# 720           NaN    NaN     GvN5rzpwQ  NaN       NaN  website
# 721           NaN    NaN     GhLB8rppQ  NaN       NaN  website
# 722           NaN    NaN     GBx6KGpBQ  NaN       NaN  website
# 723           NaN    NaN     G4276mpQQ  NaN       NaN  website
# 724           NaN    NaN     Ghw26NpPQ  NaN       NaN  website
#
#                order_place_date                req_ship_date  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 720  May 5, 2023 6:01:06 PM GMT   May 8, 2023 9:00:00 PM GMT
# 721  May 5, 2023 6:03:33 PM GMT   May 9, 2023 8:00:00 PM GMT
# 722  May 5, 2023 6:01:33 PM GMT   May 9, 2023 8:00:00 PM GMT
# 723  May 5, 2023 6:06:46 PM GMT  May 8, 2023 11:00:00 PM GMT
# 724  May 5, 2023 6:16:11 PM GMT   May 9, 2023 8:00:00 PM GMT
#
#                  ship_method                            tracking_id  \
# 0                        NaN                                    NaN
# 1                        NaN                                    NaN
# 2                        NaN                                    NaN
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
# ..                       ...                                    ...
# 720  UPS Surepost GRD Parcel  1ZB348D6YW05453343&1ZB348D6YW02147617
# 721    UPS Ground Commercial  1ZB348D60311345152&1ZB348D60311736560
# 722    UPS Ground Commercial                     1ZB348D60339372473
# 723  UPS Surepost GRD Parcel                     1ZB348D6YW01782352
# 724   UPS Ground Residential                                    NaN
#
#      num_occurences req_ship_date_diff_format
# 0                 1                       NaN
# 1                 1                       NaN
# 2                 2                       NaN
# 3                 2                       NaN
# 4                 2                       NaN
# ..              ...                       ...
# 720               2                2023-05-08
# 721               2                2023-05-09
# 722               2                2023-05-09
# 723               2                2023-05-08
# 724               2                2023-05-09
#
# [1687 rows x 12 columns]

# %%
# convert to type string for date comparisons
df_altogether['req_ship_date_diff_format'].astype('str')

# get today's date
today = datetime.datetime.now(pytz.timezone('US/Central'))
print(today)
# convert to just date in string format
today = today.strftime('%Y-%m-%d')
print(today)
# Out:
# 2023-05-05 14:03:59.567670-05:00
# 2023-05-05

# %%
# things that you want with the amazon order # of late orders:
# amz_order_num
# STATUS (not available from website)
# location (not available from website)
# order_place_date
# ship_method
# tracking_id (sometimes available if UPS order)
# req_ship_date_diff_format
late_orders = []
for i in range(len(df_altogether)):
  if df_altogether.iloc[i].loc['origin'] == 'website':
    if df_altogether.iloc[i].loc['req_ship_date_diff_format'] < today: # should get another list for orders that will be late today...
      late_orders.append([df_altogether.iloc[i].loc['amz_order_num'],
                          df_altogether.iloc[i].loc['order_place_date'],
                          df_altogether.iloc[i].loc['ship_method'],
                          df_altogether.iloc[i].loc['tracking_id'],
                          df_altogether.iloc[i].loc['req_ship_date_diff_format']])

for order in late_orders:
  print(order)
# Out:
# ['Ghmq41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GBmV4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gqm34kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['G7mp47xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GtmK4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gkm94kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GxmN4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gsmn41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GHmL4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['G4md4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gvmw41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GBq9qmJcc', 'Apr 24, 2023 10:17:07 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GBvQsws2c', 'Mar 22, 2023 4:24:31 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GBCkzhsQc', 'Apr 12, 2023 1:16:15 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GvQfswsPc', 'Aug 17, 2022 6:23:57 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW1025sLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gs1C2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gv1r2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GhlzMwsPc', 'Jul 27, 2022 7:07:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW3Hsfsmc', 'Aug 17, 2022 6:06:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['
VNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60313130077&1ZB348D60304028688', '2023-05-04']
# ['G4QTCkNyc', 'May 3, 2023 6:46:15 PM GMT', 'UPS Second Day Air', '1ZB348D60222615449', '2023-05-04']
# ['GtWKh4NTc', 'May 3, 2023 8:25:23 PM GMT', 'UPS Ground Residential', '1ZB348D60311948984', '2023-05-04']
# ['GhRlbR5xc', 'May 3, 2023 9:01:19 PM GMT', 'UPS Ground Commercial', '1ZB348D60335234049', '2023-05-04']
# ['Gsvwlbv2c', 'May 4, 2023 12:05:26 PM GMT', 'UPS Second Day Air', '1ZB348D60210896687', '2023-05-04']

# %%
# match up late order amazon order # with open order in system and append tst order #
for order in late_orders:
  for i in range(len(df_papa_as_400)): # only checking as400 orders because the info won't be found in the website orders obviously
    if order[0] == df_papa_as_400.iloc[i].loc['amz_order_num']:
      order.append(df_papa_as_400.iloc[i].loc['tst_order_num'])
      order.append(df_papa_as_400.iloc[i].loc['STATUS'])
      order.append(df_papa_as_400.iloc[i].loc['location'])
      break;

for order in late_orders:
  print(order)
# Out:
# ['Ghmq41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1493', 'OB', 98]
# ['GBmV4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1486', 'OB', 98]
# ['Gqm34kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1485', 'OB', 98]
# ['G7mp47xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1489', 'OB', 98]
# ['GtmK4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1497', 'OB', 98]
# ['Gkm94kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1499', 'OB', 98]
# ['GxmN4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1500', 'OB', 98]
# ['Gsmn41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1498', 'OB', 98]
# ['GHmL4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1524', 'OB', 98]
# ['G4md4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1527', 'OB', 98]
# ['Gvmw41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1533', 'OB', 98]
# ['GBq9qmJcc', 'Apr 24, 2023 10:17:07 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2186', 'OB', 98]
# ['GBvQsws2c', 'Mar 22, 2023 4:24:31 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2547', 'OB', 98]
# ['GBCkzhsQc', 'Apr 12, 2023 1:16:15 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2552', 'ON', 31]
# ['GvQfswsPc', 'Aug 17, 2022 6:23:57 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW1025sLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2567', 'OB', 98]
# ['Gs1C2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2566', 'OB', 98]
# ['Gv1r2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2573', 'OB', 98]
# ['GhlzMwsPc', 'Jul 27, 2022 7:07:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW3Hsfsmc', 'Aug 17, 2022 6:06:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GqHMsjsZc', 'Dec 16, 2022 2:22:35 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['G71b2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2587', 'OB', 98]
# ['GxJXLFszc', 'Nov 1, 2022 7:17:31 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gqvfccs5c', 'Nov 28, 2022 5:34:37 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gf1c25sLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2593', 'OB', 98]
# ['GBpPM8szc', 'Oct 14, 2022 11:23:34 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gqr3yL0Sc', 'Apr 26, 2023 2:24:03 AM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK3619', 'ON', 31]
# ['GvKYh5fNc', 'Mar 29, 2023 3:58:45 PM GMT', 'VOC_IMSZY', nan, '2023-04-28']
# ['GHxr30zXc', 'Apr 27, 2023 11:02:21 PM GMT', 'UPS Ground Residential', '1Z14W5600393292286', '2023-04-28', 'EK5807', 'SH', 1]
# ['GHJQSg6Tc', 'Apr 28, 2023 12:22:54 AM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK6085', 'OB', 1]
# ['G4spnBQbc', 'Apr 28, 2023 6:30:50 PM GMT', 'UPS Surepost GRD Parcel', '1Z14W560YW29036523&1Z14W560YW42989756', '2023-05-01', 'EK6435', 'OB', 1]
# ['Gk0CfmQFc', 'Apr 28, 2023 6:41:31 PM GMT', 'UPS Ground Commercial', '1ZB348D60319907352&1ZB348D60312450769', '2023-05-01', 'EK6448', 'OB', 1]
# ['GWkWR0mqc', 'May 2, 2023 1:23:15 PM GMT', 'UPS Ground Commercial', '1ZB348D60326929173&1ZB348D60320191382', '2023-05-04', 'EK8929', 'OB', 1]
# ['Gfk7R0mqc', 'May 2, 2023 1:23:15 PM GMT', 'UPS Ground Commercial', '1ZB348D60300801447&1ZB348D60310489259', '2023-05-04', 'EK8938', 'OB', 1]
# ['GhNtLlmVc', 'May 2, 2023 3:23:06 PM GMT', 'VOC_IMSZY', nan, '2023-05-04', 'EK9129', 'OB', 98]
# ['GvnQCymtc', 'May 2, 2023 5:16:59 PM GMT', 'UPS Ground Commercial', '1ZB348D60319199574', '2023-05-03', 'EK9325', 'OB', 1]
# ['GxGqFGkDc', 'May 2, 2023 5:55:55 PM GMT', 'UPS Second Day Air', '1ZB348D60209914338', '2023-05-03', 'EK9415', 'OB', 1]
# ['Gs1VPr3nc', 'Apr 24, 2023 6:30:59 PM GMT', 'UPS Next Day Air Saver', '1ZB348D61317387024', '2023-05-03', 'EK9839', 'OB', 1]
# ['GhZgxm34c', 'May 2, 2023 10:39:33 PM GMT', 'UPS Ground Residential', '1ZB348D60324847505', '2023-05-04', 'EK9846', 'OB', 1]
# ['Gq0rdWFJc', 'May 3, 2023 3:12:09 AM GMT', 'UPS Ground Residential', '1ZB348D60319053551', '2023-05-03', 'EK9997', 'OB', 1]
# ['Gt04rv4Zc', 'May 3, 2023 2:07:19 PM GMT', 'UPS Second Day Air', '1ZB348D60231708911', '2023-05-03', 'EL0229', 'OB', 1]
# ['Gs5kzNNyc', 'May 3, 2023 5:59:05 PM GMT', 'UPS Ground Commercial', '1ZB348D60309862311', '2023-05-04', 'EL0642', 'OB', 69]
# ['Gs3MqPN7c', 'May 3, 2023 6:25:47 PM GMT', 'UPS Ground Commercial', '1ZB348D60325385600', '2023-05-04', 'EL0677', 'OB', 1]
# ['GWd0JtNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60333339949&1ZB348D60337710351', '2023-05-04', 'EL0699', 'OB', 1]
# ['GsdCJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60329202148&1ZB348D60322624553', '2023-05-04', 'EL0698', 'OB', 1]
# ['G7dbJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60338429039&1ZB348D60321598843', '2023-05-04', 'EL0700', 'OB', 1]
# ['GvdrJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60313130077&1ZB348D60304028688', '2023-05-04', 'EL0704', 'OB', 1]
# ['G4QTCkNyc', 'May 3, 2023 6:46:15 PM GMT', 'UPS Second Day Air', '1ZB348D60222615449', '2023-05-04', 'EL0706', 'OB', 1]
# ['GtWKh4NTc', 'May 3, 2023 8:25:23 PM GMT', 'UPS Ground Residential', '1ZB348D60311948984', '2023-05-04', 'EL0920', 'OB', 1]
# ['GhRlbR5xc', 'May 3, 2023 9:01:19 PM GMT', 'UPS Ground Commercial', '1ZB348D60335234049', '2023-05-04', 'EL1034', 'OB', 69]
# ['Gsvwlbv2c', 'May 4, 2023 12:05:26 PM GMT', 'UPS Second Day Air', '1ZB348D60210896687', '2023-05-04', 'EL1340', 'OB', 1]

# %% [markdown]
# can group all of the VOC_IMSZY (pallet) orders and then everything left would be UPS orders of some sort unless CEVA is the carrier and that would be a problem that you should notice too

# %%
# split up late orders into pallet orders and UPS orders
late_pallet_orders = []
late_ups_orders = []
for order in late_orders:
  if order[2] == "VOC_IMSZY":
    late_pallet_orders.append(order)
  else:
    late_ups_orders.append(order)

# %%
print('pallet orders:')
for order in late_pallet_orders:
  print(order)

print('ups orders')
for order in late_ups_orders:
  print(order)
# Out:
# pallet orders:
# ['Ghmq41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1493', 'OB', 98]
# ['GBmV4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1486', 'OB', 98]
# ['Gqm34kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1485', 'OB', 98]
# ['G7mp47xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1489', 'OB', 98]
# ['GtmK4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1497', 'OB', 98]
# ['Gkm94kxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1499', 'OB', 98]
# ['GxmN4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1500', 'OB', 98]
# ['Gsmn41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1498', 'OB', 98]
# ['GHmL4mxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1524', 'OB', 98]
# ['G4md4jxNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1527', 'OB', 98]
# ['Gvmw41xNc', 'Apr 24, 2023 4:47:00 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK1533', 'OB', 98]
# ['GBq9qmJcc', 'Apr 24, 2023 10:17:07 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2186', 'OB', 98]
# ['GBvQsws2c', 'Mar 22, 2023 4:24:31 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2547', 'OB', 98]
# ['GBCkzhsQc', 'Apr 12, 2023 1:16:15 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2552', 'ON', 31]
# ['GvQfswsPc', 'Aug 17, 2022 6:23:57 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW1025sLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2567', 'OB', 98]
# ['Gs1C2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2566', 'OB', 98]
# ['Gv1r2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2573', 'OB', 98]
# ['GhlzMwsPc', 'Jul 27, 2022 7:07:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GW3Hsfsmc', 'Aug 17, 2022 6:06:32 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['GqHMsjsZc', 'Dec 16, 2022 2:22:35 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['G71b2SsLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2587', 'OB', 98]
# ['GxJXLFszc', 'Nov 1, 2022 7:17:31 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gqvfccs5c', 'Nov 28, 2022 5:34:37 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gf1c25sLc', 'Apr 11, 2023 9:32:19 PM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK2593', 'OB', 98]
# ['GBpPM8szc', 'Oct 14, 2022 11:23:34 PM GMT', 'VOC_IMSZY', nan, '2023-05-01']
# ['Gqr3yL0Sc', 'Apr 26, 2023 2:24:03 AM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK3619', 'ON', 31]
# ['GvKYh5fNc', 'Mar 29, 2023 3:58:45 PM GMT', 'VOC_IMSZY', nan, '2023-04-28']
# ['GHJQSg6Tc', 'Apr 28, 2023 12:22:54 AM GMT', 'VOC_IMSZY', nan, '2023-05-01', 'EK6085', 'OB', 1]
# ['GhNtLlmVc', 'May 2, 2023 3:23:06 PM GMT', 'VOC_IMSZY', nan, '2023-05-04', 'EK9129', 'OB', 98]
# ups orders
# ['GHxr30zXc', 'Apr 27, 2023 11:02:21 PM GMT', 'UPS Ground Residential', '1Z14W5600393292286', '2023-04-28', 'EK5807', 'SH', 1]
# ['G4spnBQbc', 'Apr 28, 2023 6:30:50 PM GMT', 'UPS Surepost GRD Parcel', '1Z14W560YW29036523&1Z14W560YW42989756', '2023-05-01', 'EK6435', 'OB', 1]
# ['Gk0CfmQFc', 'Apr 28, 2023 6:41:31 PM GMT', 'UPS Ground Commercial', '1ZB348D60319907352&1ZB348D60312450769', '2023-05-01', 'EK6448', 'OB', 1]
# ['GWkWR0mqc', 'May 2, 2023 1:23:15 PM GMT', 'UPS Ground Commercial', '1ZB348D60326929173&1ZB348D60320191382', '2023-05-04', 'EK8929', 'OB', 1]
# ['Gfk7R0mqc', 'May 2, 2023 1:23:15 PM GMT', 'UPS Ground Commercial', '1ZB348D60300801447&1ZB348D60310489259', '2023-05-04', 'EK8938', 'OB', 1]
# ['GvnQCymtc', 'May 2, 2023 5:16:59 PM GMT', 'UPS Ground Commercial', '1ZB348D60319199574', '2023-05-03', 'EK9325', 'OB', 1]
# ['GxGqFGkDc', 'May 2, 2023 5:55:55 PM GMT', 'UPS Second Day Air', '1ZB348D60209914338', '2023-05-03', 'EK9415', 'OB', 1]
# ['Gs1VPr3nc', 'Apr 24, 2023 6:30:59 PM GMT', 'UPS Next Day Air Saver', '1ZB348D61317387024', '2023-05-03', 'EK9839', 'OB', 1]
# ['GhZgxm34c', 'May 2, 2023 10:39:33 PM GMT', 'UPS Ground Residential', '1ZB348D60324847505', '2023-05-04', 'EK9846', 'OB', 1]
# ['Gq0rdWFJc', 'May 3, 2023 3:12:09 AM GMT', 'UPS Ground Residential', '1ZB348D60319053551', '2023-05-03', 'EK9997', 'OB', 1]
# ['Gt04rv4Zc', 'May 3, 2023 2:07:19 PM GMT', 'UPS Second Day Air', '1ZB348D60231708911', '2023-05-03', 'EL0229', 'OB', 1]
# ['Gs5kzNNyc', 'May 3, 2023 5:59:05 PM GMT', 'UPS Ground Commercial', '1ZB348D60309862311', '2023-05-04', 'EL0642', 'OB', 69]
# ['Gs3MqPN7c', 'May 3, 2023 6:25:47 PM GMT', 'UPS Ground Commercial', '1ZB348D60325385600', '2023-05-04', 'EL0677', 'OB', 1]
# ['GWd0JtNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60333339949&1ZB348D60337710351', '2023-05-04', 'EL0699', 'OB', 1]
# ['GsdCJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60329202148&1ZB348D60322624553', '2023-05-04', 'EL0698', 'OB', 1]
# ['G7dbJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60338429039&1ZB348D60321598843', '2023-05-04', 'EL0700', 'OB', 1]
# ['GvdrJVNgc', 'May 3, 2023 6:41:47 PM GMT', 'UPS Ground Residential', '1ZB348D60313130077&1ZB348D60304028688', '2023-05-04', 'EL0704', 'OB', 1]
# ['G4QTCkNyc', 'May 3, 2023 6:46:15 PM GMT', 'UPS Second Day Air', '1ZB348D60222615449', '2023-05-04', 'EL0706', 'OB', 1]
# ['GtWKh4NTc', 'May 3, 2023 8:25:23 PM GMT', 'UPS Ground Residential', '1ZB348D60311948984', '2023-05-04', 'EL0920', 'OB', 1]
# ['GhRlbR5xc', 'May 3, 2023 9:01:19 PM GMT', 'UPS Ground Commercial', '1ZB348D60335234049', '2023-05-04', 'EL1034', 'OB', 69]
# ['Gsvwlbv2c', 'May 4, 2023 12:05:26 PM GMT', 'UPS Second Day Air', '1ZB348D60210896687', '2023-05-04', 'EL1340', 'OB', 1]

# %%
# separate late_pallet_orders and late_ups_orders by shipping location
# guess that you can just hard code the different locations since plant locations will not change
tx_late_pallet_orders = []
fl_late_pallet_orders = []
pa_late_pallet_orders = []
il_late_pallet_orders = []
ca_late_pallet_orders = []
ninetyeight_late_pallet_orders = []
loc_not_found_late_pallet_orders = []

tx_late_ups_orders = []
fl_late_ups_orders = []
pa_late_ups_orders = []
il_late_ups_orders = []
ca_late_ups_orders = []
loc_not_found_late_ups_orders = []

for order in late_pallet_orders:
  # need to check size of order list 1st because sometimes there was not a matching order to be found and then no location added
  # so that would be a separate list of no location matched up orders
  if len(order) < 8:
    loc_not_found_late_pallet_orders.append(order)
  else:
    if order[7] == 1:
      tx_late_pallet_orders.append(order)
    elif order[7] == 31:
      fl_late_pallet_orders.append(order)
    elif order[7] == 60:
      pa_late_pallet_orders.append(order)
    elif order[7] == 69:
      il_late_pallet_orders.append(order)
    elif order[7] == 75:
      ca_late_pallet_orders.append(order)
    elif order[7] == 98:
      ninetyeight_late_pallet_orders.append(order)

for order in late_ups_orders:
  # need to check size of order list 1st because sometimes there was not a matching order to be found and then no location added
  # so that would be a separate list of no location matched up orders
  if len(order) < 8:
    loc_not_found_late_ups_orders.append(order)
  else:
    if order[7] == 1:
      tx_late_ups_orders.append(order)
    elif order[7] == 31:
      fl_late_ups_orders.append(order)
    elif order[7] == 60:
      pa_late_ups_orders.append(order)
    elif order[7] == 69:
      il_late_ups_orders.append(order)
    elif order[7] == 75:
      ca_late_ups_orders.append(order)

# %%
# sort all of the late orders by status
sorted_ninetyeight_late_pallet_orders = sorted(ninetyeight_late_pallet_orders, key=lambda x: x[6])
sorted_tx_late_pallet_orders = sorted(tx_late_pallet_orders, key=lambda x: x[6])
sorted_fl_late_pallet_orders = sorted(fl_late_pallet_orders, key=lambda x: x[6])
sorted_pa_late_pallet_orders = sorted(pa_late_pallet_orders, key=lambda x: x[6])
sorted_il_late_pallet_orders = sorted(il_late_pallet_orders, key=lambda x: x[6])
sorted_ca_late_pallet_orders = sorted(ca_late_pallet_orders, key=lambda x: x[6])

# %%
# print all of the late orders out by location
print('01 LATE UPS ORDERS:')
for order in tx_late_ups_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('31 LATE UPS ORDERS:')
for order in fl_late_ups_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('60 LATE UPS ORDERS:')
for order in pa_late_ups_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('69 LATE UPS ORDERS:')
for order in il_late_ups_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('75 LATE UPS ORDERS:')
for order in ca_late_ups_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('NO LOCATION FOUND LATE UPS ORDERS:')
for order in loc_not_found_late_ups_orders:
  print(f"{order[0]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")

print('\n********************')
print('98 LATE PALLET ORDERS:')
for order in sorted_ninetyeight_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('01 LATE PALLET ORDERS:')
for order in sorted_tx_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('31 LATE PALLET ORDERS:')
for order in sorted_fl_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('60 LATE PALLET ORDERS:')
for order in sorted_pa_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('69 LATE PALLET ORDERS:')
for order in sorted_il_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('75 LATE PALLET ORDERS:')
for order in sorted_ca_late_pallet_orders:
  print(f"{order[5]} {order[0]} {order[6]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
print('\n********************')
print('NO LOCATION FOUND LATE PALLET ORDERS:')
for order in loc_not_found_late_pallet_orders:
  print(f"{order[0]} SHIP BY: {order[4]} ORDER PLACED: {order[1]}")
# Out:
# 01 LATE UPS ORDERS:
# EK5807 GHxr30zXc SH SHIP BY: 2023-04-28 ORDER PLACED: Apr 27, 2023 11:02:21 PM GMT
# EK6435 G4spnBQbc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 28, 2023 6:30:50 PM GMT
# EK6448 Gk0CfmQFc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 28, 2023 6:41:31 PM GMT
# EK8929 GWkWR0mqc OB SHIP BY: 2023-05-04 ORDER PLACED: May 2, 2023 1:23:15 PM GMT
# EK8938 Gfk7R0mqc OB SHIP BY: 2023-05-04 ORDER PLACED: May 2, 2023 1:23:15 PM GMT
# EK9325 GvnQCymtc OB SHIP BY: 2023-05-03 ORDER PLACED: May 2, 2023 5:16:59 PM GMT
# EK9415 GxGqFGkDc OB SHIP BY: 2023-05-03 ORDER PLACED: May 2, 2023 5:55:55 PM GMT
# EK9839 Gs1VPr3nc OB SHIP BY: 2023-05-03 ORDER PLACED: Apr 24, 2023 6:30:59 PM GMT
# EK9846 GhZgxm34c OB SHIP BY: 2023-05-04 ORDER PLACED: May 2, 2023 10:39:33 PM GMT
# EK9997 Gq0rdWFJc OB SHIP BY: 2023-05-03 ORDER PLACED: May 3, 2023 3:12:09 AM GMT
# EL0229 Gt04rv4Zc OB SHIP BY: 2023-05-03 ORDER PLACED: May 3, 2023 2:07:19 PM GMT
# EL0677 Gs3MqPN7c OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:25:47 PM GMT
# EL0699 GWd0JtNgc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:41:47 PM GMT
# EL0698 GsdCJVNgc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:41:47 PM GMT
# EL0700 G7dbJVNgc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:41:47 PM GMT
# EL0704 GvdrJVNgc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:41:47 PM GMT
# EL0706 G4QTCkNyc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 6:46:15 PM GMT
# EL0920 GtWKh4NTc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 8:25:23 PM GMT
# EL1340 Gsvwlbv2c OB SHIP BY: 2023-05-04 ORDER PLACED: May 4, 2023 12:05:26 PM GMT
#
# ********************
# 31 LATE UPS ORDERS:
#
# ********************
# 60 LATE UPS ORDERS:
#
# ********************
# 69 LATE UPS ORDERS:
# EL0642 Gs5kzNNyc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 5:59:05 PM GMT
# EL1034 GhRlbR5xc OB SHIP BY: 2023-05-04 ORDER PLACED: May 3, 2023 9:01:19 PM GMT
#
# ********************
# 75 LATE UPS ORDERS:
#
# ********************
# NO LOCATION FOUND LATE UPS ORDERS:
#
# ********************
# 98 LATE PALLET ORDERS:
# EK1493 Ghmq41xNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1486 GBmV4jxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1485 Gqm34kxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1489 G7mp47xNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1497 GtmK4mxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1499 Gkm94kxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1500 GxmN4mxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1498 Gsmn41xNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1524 GHmL4mxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1527 G4md4jxNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK1533 Gvmw41xNc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 4:47:00 PM GMT
# EK2186 GBq9qmJcc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 24, 2023 10:17:07 PM GMT
# EK2547 GBvQsws2c OB SHIP BY: 2023-05-01 ORDER PLACED: Mar 22, 2023 4:24:31 PM GMT
# EK2567 GW1025sLc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 11, 2023 9:32:19 PM GMT
# EK2566 Gs1C2SsLc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 11, 2023 9:32:19 PM GMT
# EK2573 Gv1r2SsLc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 11, 2023 9:32:19 PM GMT
# EK2587 G71b2SsLc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 11, 2023 9:32:19 PM GMT
# EK2593 Gf1c25sLc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 11, 2023 9:32:19 PM GMT
# EK9129 GhNtLlmVc OB SHIP BY: 2023-05-04 ORDER PLACED: May 2, 2023 3:23:06 PM GMT
#
# ********************
# 01 LATE PALLET ORDERS:
# EK6085 GHJQSg6Tc OB SHIP BY: 2023-05-01 ORDER PLACED: Apr 28, 2023 12:22:54 AM GMT
#
# ********************
# 31 LATE PALLET ORDERS:
# EK2552 GBCkzhsQc ON SHIP BY: 2023-05-01 ORDER PLACED: Apr 12, 2023 1:16:15 PM GMT
# EK3619 Gqr3yL0Sc ON SHIP BY: 2023-05-01 ORDER PLACED: Apr 26, 2023 2:24:03 AM GMT
#
# ********************
# 60 LATE PALLET ORDERS:
#
# ********************
# 69 LATE PALLET ORDERS:
#
# ********************
# 75 LATE PALLET ORDERS:
#
# ********************
# NO LOCATION FOUND LATE PALLET ORDERS:
# GvQfswsPc SHIP BY: 2023-05-01 ORDER PLACED: Aug 17, 2022 6:23:57 PM GMT
# GhlzMwsPc SHIP BY: 2023-05-01 ORDER PLACED: Jul 27, 2022 7:07:32 PM GMT
# GW3Hsfsmc SHIP BY: 2023-05-01 ORDER PLACED: Aug 17, 2022 6:06:32 PM GMT
# GqHMsjsZc SHIP BY: 2023-05-01 ORDER PLACED: Dec 16, 2022 2:22:35 PM GMT
# GxJXLFszc SHIP BY: 2023-05-01 ORDER PLACED: Nov 1, 2022 7:17:31 PM GMT
# Gqvfccs5c SHIP BY: 2023-05-01 ORDER PLACED: Nov 28, 2022 5:34:37 PM GMT
# GBpPM8szc SHIP BY: 2023-05-01 ORDER PLACED: Oct 14, 2022 11:23:34 PM GMT
# GvKYh5fNc SHIP BY: 2023-04-28 ORDER PLACED: Mar 29, 2023 3:58:45 PM GMT

# %%
# write late orders to csv file
# filename = path_to_this_dir + 'late_orders.csv' # if you want to mount google drive to pull files and write files in your cloud storage
filename = 'late_orders.csv'
with open(filename, 'w') as csvfile:
  csvwriter = csv.writer(csvfile)

  csvwriter.writerow(['01 LATE UPS ORDERS:'])
  for order in tx_late_ups_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)
  
  csvwriter.writerow(['\n'])
  csvwriter.writerow(['31 LATE UPS ORDERS:'])
  for order in fl_late_ups_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['60 LATE UPS ORDERS:'])
  for order in pa_late_ups_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['69 LATE UPS ORDERS:'])
  for order in il_late_ups_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['75 LATE UPS ORDERS:'])
  for order in ca_late_ups_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['NO LOCATION FOUND LATE UPS ORDERS:'])
  for order in loc_not_found_late_ups_orders:
    one_line = []
    one_line.append(order[0])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['98 LATE PALLET ORDERS:'])
  for order in sorted_ninetyeight_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['01 LATE PALLET ORDERS:'])
  for order in sorted_tx_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['31 LATE PALLET ORDERS:'])
  for order in sorted_fl_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['60 LATE PALLET ORDERS:'])
  for order in sorted_pa_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['69 LATE PALLET ORDERS:'])
  for order in sorted_il_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['75 LATE PALLET ORDERS:'])
  for order in sorted_ca_late_pallet_orders:
    one_line = []
    one_line.append(order[5])
    one_line.append(order[0])
    one_line.append(order[6])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)

  csvwriter.writerow(['\n'])
  csvwriter.writerow(['NO LOCATION FOUND LATE PALLET ORDERS:'])
  for order in loc_not_found_late_pallet_orders:
    one_line = []
    one_line.append(order[0])
    one_line.append('SHIP BY: ' + order[4])
    one_line.append('ORDER PLACED: ' + order[1])

    csvwriter.writerow(one_line)
